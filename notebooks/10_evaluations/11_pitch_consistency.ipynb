# %% [markdown]
# ## 11 Pitch Consistency
#
# Explores simple question: Does generated audio match the target pitch?

# %%
import numpy as np 
import torch 
import torch.nn.functional as F
import pandas as pd 
import sys 
import os 
import yaml 
import time
from IPython.display import Audio, display
import torchcrepe
from dotenv import load_dotenv

dotenv_path = '/home/robbizorg/classes/RT_MusicGen'
load_dotenv(dotenv_path=dotenv_path)

music_path = os.getenv("music_path")
sf_path = os.getenv('sf_path')
sample_path = os.getenv('sample_path')

sys.path.append('../../')
from src.spectral_ops import ISTFT, STFT
from src.models import Vocos
from src.encoder import TimbreEncoder
from src.dataset import Midi_Seg, train_collate_fn
from src.utils import hz_to_nearest_midi

# %%
# Load in Base Config'
yaml_name = 'midi_vocos_1st.yaml'
with open('../../yamls/' + yaml_name, "r") as stream:
    try:
        config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

device = 'cpu' # Running all Tests on the CPU 
sample_rate = config['sample_rate']
buffer_size = config['buffer_size']
prev_ratio = config.get('prev_ratio', 2.0)
comment = config['comment']
ckpt_path = os.path.join('../../ckpt', comment)

vocos_config = config['vocos_config']   

# Load Models
model = Vocos(vocos_config).to(device)
model.load_state_dict(torch.load(os.path.join(ckpt_path, '30', 'VocosSynth.pth'), map_location=device))
model.eval()

timbre_config = config['timbre_config']  
tmbr_encoder = TimbreEncoder(timbre_config).to(device)
tmbr_encoder.load_state_dict(torch.load(os.path.join(ckpt_path, '30', 'VocosTimbre.pth'), map_location=device))
tmbr_encoder.eval()

# Init Transform
stft_transform = STFT(
    n_fft=vocos_config['head']['n_fft'],
    hop_length=vocos_config['head']['hop_length'],
    win_length=vocos_config['head']['n_fft']
).to(device)


# Load Dataset
train_dataset = Midi_Seg(sf_path = sample_path, 
    sr = sample_rate, 
    buffer_size = buffer_size, 
    prev_ratio = prev_ratio)

# %%
idxes = np.random.choice(list(range(len(train_dataset))), size = 100)
tgt_pitches = []
est_pitches = []
gen_times = []
for idx in idxes: 
    ex_path = train_dataset.files[idx]
    print(f'Loading {ex_path}')


    x_raw, pitch, _, _ = train_dataset.__getitem__(idx)
    x_raw = x_raw.unsqueeze(0)
    pitch = pitch.unsqueeze(0)

    # Where idx sampling can begin and end 
    start_idx = int(buffer_size * prev_ratio)
    end_idx = int(x_raw.shape[-1] - buffer_size)

    # Pad by Prev Ratio
    pad_len = int(buffer_size * prev_ratio)
    x = F.pad(x_raw, pad=(pad_len, 0))

    # Get Beginning (should be just 0s)
    prev_x = x[:, start_idx - pad_len : start_idx].float() # Previous Info

    timbre_x = x[:, start_idx : start_idx + sample_rate].float()

    # Process Timbre 
    timbre_spec = stft_transform(timbre_x)
    timbre_emb = tmbr_encoder(timbre_spec)

    # Process Inputs and Estimate next step
    all_out = torch.tensor([])

    # Generate at least 4s of Audio
    while all_out.shape[-1] < sample_rate * 4:
        start_time = time.time()
        prev_spec = stft_transform(prev_x)

        if len(pitch.shape) != 3:
            pitch_review = pitch[:, None, None].repeat(1, 1, prev_spec.shape[-1]).float().to(device)


        in_feats = torch.cat([pitch_review, prev_spec], dim = 1)

        with torch.no_grad():
            out = model(in_feats, timbre_emb=timbre_emb)

        # Match Time
        x_hat = out[:, :buffer_size]
        end_time = time.time()
        gen_times.append(end_time - start_time)

        # Move buffer
        prev_x = torch.cat([prev_x[:, buffer_size:], x_hat], dim = 1)
        # Append to all out
        all_out = torch.cat([all_out, x_hat], dim = 1)
     
    # Calculate Pitch and see if matches
    est_pitch_trace = torchcrepe.predict(all_out.to('cuda'),
                            sample_rate,
                            sample_rate // 200,
                            25, # Min Midi is 21
                            4500, # Max Midi is 109
                            'tiny', # Use Tiny Model for speed
                            batch_size=1,
                            device='cuda') # Run on GPU for speed
    
    est_pitch = hz_to_nearest_midi(est_pitch_trace.mean().cpu().numpy().item())

    tgt_pitches.append(pitch[0].item())
    est_pitches.append(est_pitch)

tgt_pitches = np.array(tgt_pitches)
est_pitches = np.array(est_pitches)

avg_err = np.abs(tgt_pitches - est_pitches).mean() 
print(f'Average Absolute Midi Error: {avg_err}')
# Out:
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Freepats-MutedGuitar/50_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Sax-Section/72_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Iowa-Tuba/88_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Church-Choir-2/78_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Footsteps/104_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Lithalean-AcousticGt/93_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Lead-2q/75_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/EightSixteen-E.Piano/60_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Dist.Muted-Guitar/106_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Sweep-Pad/60_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Lead-2y/98_80.wav
# Loading /data/robbizorg/music/samples/Touhou/808-Tom/57_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Taiko-Drum/62_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/DSoundFont-Whistle/75_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Distorted-Acid-Bass/103_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Lead-5-Charang/28_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/SynthFX-4-Atmosphere/101_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Wind-Chime/31_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-FX-1d/58_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/SlowIowaTrem.Strings/26_80.wav
# Loading /data/robbizorg/music/samples/Touhou/MM-THUMBS-A/31_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/SGM-GS-Ethnic-Kit/90_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/SynthLead2b-Pulsesaw/89_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-FX-8---Sci-Fi/93_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/STGIGA-TapeRewind/90_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Concert-Bass-Drum/58_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Sweet-Iowa-Trumpet/39_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/MK-Tremolo-Mandolin/77_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Resonant-MK-Clavi/26_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Muted-Horns/107_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Elf's-Dream-Pad/63_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Octave-Rave/30_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Strings-1/83_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Telephone-2/108_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Stereo-Tenor-Sax/98_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Brass-Fall-2/28_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/E-Mu-60's-Organ-2/24_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/MK-Reverse-Cymbal/79_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/DanceSalamanderPiano/55_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Tremolo-Ethnic-Flute/108_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Castanets/45_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/5th-Synth-Bass/21_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/SynthLead-1---Square/96_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Horns/41_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Chorus-SynthStrings/35_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Dizi/50_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Hybrid-Strings/64_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Octave-JS-Harp/100_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Ottos-Fretless-Bass/72_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Palm-Muted-Guitar/40_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Strings-Section/46_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Organ-Flute/60_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Guitar-Pinch/85_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Horn-+-Strings-+-Trp/27_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/SynthLead2b-Pulsesaw/34_80.wav
# Loading /data/robbizorg/music/samples/Touhou/DrawbarOrgan/40_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/EnhncdSGM-SynPd7Halo/49_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Glass-816-El.Piano/75_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Church-Choir/108_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/STGIGA-Scratch-2/79_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Ocarina/37_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Fast-Atk-Iowa-Viola/31_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Rising-Oscillator/42_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Deephouse-Lead/22_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Lead-2r/35_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/FM-Beef-Bass/38_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Sea-Shore/53_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/STGIGA-Angklung/80_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Organ-Hit/79_80.wav
# Loading /data/robbizorg/music/samples/Touhou/prc:Marimba/82_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/OSDK-Tom-2/52_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Stgiga-LP-OverDrv:/49_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Car-Crash/96_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Breathy-Iowa-AltoSax/53_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Tremolo-JRhodes-EP/78_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/OS-Rock-Tom/29_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Explosion/59_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Feedback-Guitar/28_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-FX-5a/61_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Chorus-Drawbar-Organ/47_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Ahh-Choir/21_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Strings-+-Sine/87_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Strings-Orchest/88_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Cimbalom/68_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Legato-Yuri-Piccolo/51_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Spatial-Sal.GrandPno/48_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Bass-20/79_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Lead-8c/48_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Punch/22_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Strings-+-Choir/91_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/SGM-GS-StandardKit1/77_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Clavi/81_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Banjo/88_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Strings-9/48_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Synth-Lead-5c/99_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Stereo-FM-El.Piano/22_80.wav
# Loading /data/robbizorg/music/samples/Touhou/Bowed-Glass/52_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Distorted-Acid-Bass/68_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/STGIGA-Noise-Piano/55_80.wav
# Loading /data/robbizorg/music/samples/DSoundfont_Ultimate/Funk-Guitar/75_80.wav
# Average Absolute Midi Error: 32.31

# %%
print(f'Average Generation Latency: {round(np.mean(gen_times), 5)*1000}ms')
print(f'Median Generation Latency: {round(np.median(gen_times), 5)*1000}ms')
print(f'Max Generation Latency: {round(np.max(gen_times), 5)*1000}ms')
# Out:
# Average Generation Latency: 25.4ms
# Median Generation Latency: 8.27ms
# Max Generation Latency: 1490.99ms
